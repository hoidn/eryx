# %%
import visualize_diffuse

# %%
inp = visualize_diffuse.main('np')
# Out:
# Using dataset: np_diffuse_intensity.npy
# Diffuse intensity shape: (450625,)
# Reshaped diffuse intensity to: (25, 103, 175)

# %%
itorch = visualize_diffuse.main('torch')
# Out:
# Using dataset: torch_diffuse_intensity.npy
# Diffuse intensity shape: (450625,)
# Reshaped diffuse intensity to: (25, 103, 175)

# %%
inp[0][0][:50], itorch[0][0][:50], (inp - itorch)[0][0][:50]
# Out:
# (array([          nan,  814.45945464,  911.61044342,           nan,
#          961.23921889,  966.48178567,           nan,  806.92375731,
#          672.59351642,           nan,  733.23165715,  598.30250327,
#                   nan,  134.66148565,  143.16500344,           nan,
#         2201.98547952, 1452.75507329,           nan,  737.03814755,
#          141.1124215 ,           nan, 3015.98079587,  876.65627642,
#                   nan,  281.48996317,  595.95626534,           nan,
#          239.43295321,  346.7365861 ,           nan, 2130.738883  ,
#          547.66462109,           nan,  298.38786962, 2256.19166471,
#                   nan, 2286.74430684,  405.22118649,           nan,
#         1202.09584324, 1408.9105522 ,           nan,  424.01128983,
#          843.58774405,           nan,  514.77307804,   71.45048481,
#                   nan, 1243.18274933]),
#  array([       nan,  814.4674 ,  911.6245 ,        nan,  961.25354,
#          966.49286,        nan,  806.93726,  672.60785,        nan,
#          733.23456,  598.3079 ,        nan,  134.66505,  143.16862,
#                nan, 2202.0244 , 1452.776  ,        nan,  737.0443 ,
#          141.11005,        nan, 3016.021  ,  876.6644 ,        nan,
#          281.4899 ,  595.9657 ,        nan,  239.43085,  346.7372 ,
#                nan, 2130.7666 ,  547.68036,        nan,  298.38983,
#         2256.2134 ,        nan, 2286.7703 ,  405.22632,        nan,
#         1202.1152 , 1408.9353 ,        nan,  424.0186 ,  843.60156,
#                nan,  514.7851 ,   71.45069,        nan, 1243.1973 ],
#        dtype=float32),
#  array([            nan, -7.95258220e-03, -1.40682979e-02,             nan,
#         -1.43211481e-02, -1.10732155e-02,             nan, -1.34985510e-02,
#         -1.43326992e-02,             nan, -2.90095765e-03, -5.41909423e-03,
#                     nan, -3.56866913e-03, -3.62143718e-03,             nan,
#         -3.89345424e-02, -2.09276853e-02,             nan, -6.16397403e-03,
#          2.37511364e-03,             nan, -4.02002197e-02, -8.15228760e-03,
#                     nan,  6.44850837e-05, -9.43290587e-03,             nan,
#          2.10604426e-03, -6.27036352e-04,             nan, -2.77185645e-02,
#         -1.57377986e-02,             nan, -1.96192157e-03, -2.17141978e-02,
#                     nan, -2.59568311e-02, -5.13186670e-03,             nan,
#         -1.93911315e-02, -2.47505315e-02,             nan, -7.29537965e-03,
#         -1.38184503e-02,             nan, -1.20171767e-02, -2.06417477e-04,
#                     nan, -1.45162919e-02]))

# %%
# %run visualize_diffuse.py --dataset torch
# Out:
# Using dataset: torch_diffuse_intensity.npy
# Diffuse intensity shape: (450625,)
# Reshaped diffuse intensity to: (25, 103, 175)

# %%
# %run visualize_diffuse.py --dataset np
# Out:
# Using dataset: np_diffuse_intensity.npy
# Diffuse intensity shape: (450625,)
# Reshaped diffuse intensity to: (25, 103, 175)

# %%
intensity = main()
# Out:
# Using dataset: torch_diffuse_intensity.npy
# Diffuse intensity shape: (450625,)
# Reshaped diffuse intensity to: (25, 103, 175)

# %%
intensity
# Out:
# array([[[        nan,  814.4674  ,  911.6245  , ...,  126.09391 ,
#           103.40092 ,         nan],
#         [ 557.2792  ,  697.2629  ,  411.25992 , ...,  399.34213 ,
#           225.18729 ,  557.3074  ],
#         [1153.8102  ,  773.7184  ,  428.53207 , ...,  714.6033  ,
#           599.7637  , 1153.862   ],
#         ...,
#         [ 667.85596 ,  338.36917 ,  185.9307  , ...,  215.11646 ,
#           577.141   ,  667.82086 ],
#         [ 237.09026 ,  150.99748 ,  134.56435 , ...,  239.71811 ,
#           468.35297 ,  237.08641 ],
#         [        nan,  103.39896 ,  126.09689 , ...,  911.61285 ,
#           814.4658  ,         nan]],
#
#        [[  40.235886,  109.306595,  149.61926 , ...,   47.945995,
#            35.744583,   45.09192 ],
#         [  38.47964 ,  118.062386,  138.21266 , ...,  101.03673 ,
#           106.87769 ,  115.4996  ],
#         [  17.569275,  161.49901 ,  179.89462 , ...,   79.868515,
#           110.512   ,  137.1267  ],
#         ...,
#         [  23.275154,   19.004234,   36.96989 , ...,   50.46382 ,
#            27.08963 ,  113.90326 ],
#         [  20.650066,   15.958699,   25.6699  , ...,   34.31186 ,
#            69.57313 ,  104.10682 ],
#         [  40.235706,   36.89553 ,   42.620026, ...,   46.91175 ,
#            95.72017 ,   45.092716]],
#
#        [[  81.8693  ,   81.56303 ,  161.0425  , ...,   70.77758 ,
#            56.927013,   58.670452],
#         [  73.93753 ,   90.15521 ,  191.07338 , ...,  101.43804 ,
#           107.52899 ,  113.12288 ],
#         [  31.405998,  128.34256 ,  235.15988 , ...,   87.10329 ,
#            96.00395 ,  110.966255],
#         ...,
#         [  28.974463,   19.612572,   28.902254, ...,   56.863846,
#            16.780188,  122.6211  ],
#         [  17.153427,   15.689954,   21.769659, ...,   25.387365,
#            25.191832,   85.71828 ],
#         [  81.86897 ,   56.79971 ,   73.28413 , ...,   22.841543,
#            31.906803,   58.671238]],
#
#        ...,
#
#        [[  58.671246,   31.906797,   22.841541, ...,   73.28413 ,
#            56.799706,   81.86898 ],
#         [  85.71827 ,   25.191832,   25.387363, ...,   21.769653,
#            15.689955,   17.153425],
#         [ 122.62112 ,   16.780184,   56.863853, ...,   28.902262,
#            19.612568,   28.974472],
#         ...,
#         [ 110.96624 ,   96.003944,   87.10328 , ...,  235.1599  ,
#           128.34258 ,   31.406008],
#         [ 113.122856,  107.52899 ,  101.43804 , ...,  191.07336 ,
#            90.15522 ,   73.93753 ],
#         [  58.670444,   56.92703 ,   70.777565, ...,  161.0425  ,
#            81.56302 ,   81.86931 ]],
#
#        [[  45.092716,   95.72018 ,   46.911755, ...,   42.620018,
#            36.895527,   40.235706],
#         [ 104.10682 ,   69.573135,   34.311855, ...,   25.669899,
#            15.958695,   20.650059],
#         [ 113.90327 ,   27.08963 ,   50.463818, ...,   36.96989 ,
#            19.004234,   23.275156],
#         ...,
#         [ 137.1267  ,  110.51199 ,   79.868515, ...,  179.89464 ,
#           161.49901 ,   17.569275],
#         [ 115.49962 ,  106.8777  ,  101.03674 , ...,  138.21266 ,
#           118.06238 ,   38.479652],
#         [  45.09192 ,   35.74458 ,   47.945988, ...,  149.61931 ,
#           109.306595,   40.235886]],
#
#        [[        nan,  814.4658  ,  911.61285 , ...,  126.0969  ,
#           103.39897 ,         nan],
#         [ 237.08641 ,  468.35297 ,  239.71811 , ...,  134.56436 ,
#           150.99748 ,  237.09026 ],
#         [ 667.8209  ,  577.141   ,  215.11647 , ...,  185.93071 ,
#           338.36917 ,  667.8559  ],
#         ...,
#         [1153.8622  ,  599.76373 ,  714.6032  , ...,  428.53207 ,
#           773.71844 , 1153.8103  ],
#         [ 557.30743 ,  225.18729 ,  399.34207 , ...,  411.25992 ,
#           697.2629  ,  557.2792  ],
#         [        nan,  103.4009  ,  126.09391 , ...,  911.6245  ,
#           814.46747 ,         nan]]], dtype=float32)

# %%
plt.hist(intensity[intensity < 1e4].ravel(), bins = 100)
plt.semilogy()
plt.grid()
